# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
mtalbert = pd.read_csv('../Data/soil data/AcrossAucklandRainfallStation/MtAlbert_Data_15mins.csv', parse_dates=['Timestamp (UTC+12:00)'])
mtalbert.head()
# Out:
#   Timestamp (UTC+12:00)  Rain(mm)  SoilTemp(c)  SoilMoisture(%)
# 0   2018-07-07 11:15:00       0.0         10.4           37.364
# 1   2018-07-07 11:30:00       0.0         10.4           37.594
# 2   2018-07-07 11:45:00       0.0         10.4           37.590
# 3   2018-07-07 12:00:00       0.0         10.5           37.587
# 4   2018-07-07 12:15:00       0.0         10.5           37.584

# %%
mtalbert.describe()
# Out:
#                Timestamp (UTC+12:00)       Rain(mm)    SoilTemp(c)  \
# count                         187529  187529.000000  187529.000000
# mean   2022-01-17 07:48:29.501997312       0.038837      17.079976
# min              2018-07-07 11:15:00       0.000000       9.400000
# 25%              2020-09-13 19:00:00       0.000000      13.900000
# 50%              2022-01-15 04:15:00       0.000000      16.700000
# 75%              2023-05-21 10:15:00       0.000000      20.400000
# max              2024-10-21 20:00:00      14.000000      25.400000
# std                              NaN       0.273190       3.665015
#
#        SoilMoisture(%)
# count    187529.000000
# mean         43.446207
# min          34.323000
# 25%          38.480000
# 50%          44.229000
# 75%          47.577000
# max          53.250000
# std           5.155842

# %%
ararimu = pd.read_csv('../Data/soil data/AcrossAucklandRainfallStation/ArarimuCombined_Data_15mins.csv', parse_dates=['Timestamp (UTC+12:00)'])
ararimu.head()
# Out:
#   Timestamp (UTC+12:00)  Rain(mm)  SoilTemp(c)  SoilMoisture(%)  Column1
# 0   2014-05-29 03:45:00       0.0          9.7           44.279      NaN
# 1   2014-05-29 04:00:00       0.0          9.7           44.279      NaN
# 2   2014-05-29 04:15:00       0.0          9.7           44.279      NaN
# 3   2014-05-29 04:30:00       0.0          9.5           44.167      NaN
# 4   2014-05-29 04:45:00       0.0          9.5           44.165      NaN

# %%
ararimu.describe()
# Out:
#                Timestamp (UTC+12:00)       Rain(mm)    SoilTemp(c)  \
# count                         323818  323818.000000  323818.000000
# mean   2019-08-26 20:05:59.721509888       0.043513      16.411810
# min              2014-05-29 03:45:00       0.000000       5.200000
# 25%              2016-09-18 10:18:45       0.000000      13.100000
# 50%              2020-01-28 06:52:30       0.000000      16.100000
# 75%              2022-05-20 13:26:15       0.000000      19.600000
# max              2024-09-09 21:30:00      18.920000      29.900000
# std                              NaN       0.298592       3.929877
#
#        SoilMoisture(%)  Column1
# count    323818.000000      0.0
# mean         46.706767      NaN
# min          30.951000      NaN
# 25%          42.275000      NaN
# 50%          48.078000      NaN
# 75%          51.575000      NaN
# max          69.878000      NaN
# std           6.495553      NaN

# %%
# Save the combined data to a new CSV file
awhitu = pd.read_csv('../Data/soil data/AcrossAucklandRainfallStation/awhituCombined_Data_15mins.csv', parse_dates=['Timestamp (UTC+12:00)'])
awhitu.head()
# Out:
#   Timestamp (UTC+12:00)  Rain(mm)  SoilTemp(c)  SoilMoisture(%)  Column1  \
# 0   2014-05-27 17:45:00       0.0         14.2           43.589      NaN
# 1   2014-05-27 18:00:00       0.0         14.2           43.587      NaN
# 2   2014-05-27 18:15:00       0.0         14.0           43.586      NaN
# 3   2014-05-27 18:30:00       0.0         14.0           43.561      NaN
# 4   2014-05-27 18:45:00       0.0         13.9           43.561      NaN
#
#    Column2
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN

# %%
awhitu.describe()
# Out:
#                Timestamp (UTC+12:00)       Rain(mm)    SoilTemp(c)  \
# count                         272586  272586.000000  272575.000000
# mean   2019-09-11 22:37:39.324029952       0.039299      17.897929
# min              2014-05-27 17:45:00       0.000000       7.900000
# 25%              2016-05-07 01:18:45       0.000000      13.900000
# 50%              2020-08-13 07:22:30       0.000000      17.400000
# 75%              2022-07-31 03:56:15       0.000000      21.600000
# max              2024-09-10 21:45:00      23.060000      30.300000
# std                              NaN       0.285745       4.529196
#
#        SoilMoisture(%)  Column1  Column2
# count    272586.000000      0.0      0.0
# mean         44.931976      NaN      NaN
# min          31.342000      NaN      NaN
# 25%          42.481000      NaN      NaN
# 50%          45.801500      NaN      NaN
# 75%          47.157000      NaN      NaN
# max          53.619000      NaN      NaN
# ...

# %%
hoteo = pd.read_csv('../Data/soil data/AcrossAucklandRainfallStation/hoteoCombined_Data_15mins.csv', parse_dates=['Timestamp (UTC+12:00)'])
hoteo.head()
# Out:
#   Timestamp (UTC+12:00)  Rain(mm)  SoilTemp(c)  SoilMoisture(%)
# 0   2023-02-08 05:15:00       0.0         21.8           47.376
# 1   2023-02-08 05:30:00       0.0         21.7           47.472
# 2   2023-02-08 05:45:00       0.0         21.6           47.472
# 3   2023-02-08 06:00:00       0.0         21.5           47.472
# 4   2023-02-08 06:15:00       0.0         21.4           47.472

# %%
kaipara = pd.read_csv('../Data/soil data/AcrossAucklandRainfallStation/Kaipara_Data_15mins.csv', parse_dates=['Timestamp (UTC+12:00)'])
kaipara.head()
# Out:
#   Timestamp (UTC+12:00)  Rain(mm)  SoilTemp(c)  SoilMoisture(%)
# 0   2014-07-08 00:30:00       0.0         13.4           39.218
# 1   2014-07-08 00:45:00       0.0         13.3           39.220
# 2   2014-07-08 01:00:00       0.0         13.3           39.220
# 3   2014-07-08 01:15:00       0.0         13.3           39.220
# 4   2014-07-08 01:30:00       0.0         13.3           39.221

# %%
kaipara.describe()
# Out:
#                Timestamp (UTC+12:00)       Rain(mm)    SoilTemp(c)  \
# count                         328399  328399.000000  328399.000000
# mean   2019-08-28 11:57:43.464870656       0.033018      17.596703
# min              2014-07-08 00:30:00       0.000000       7.000000
# 25%              2016-11-09 05:22:30       0.000000      13.900000
# 50%              2019-12-27 21:00:00       0.000000      17.000000
# 75%              2022-05-08 15:22:30       0.000000      21.000000
# max              2024-09-09 21:45:00      15.090000      33.100000
# std                              NaN       0.248721       4.404020
#
#        SoilMoisture(%)
# count    328399.000000
# mean         36.080888
# min          26.181667
# 25%          33.121000
# 50%          37.293000
# 75%          39.032500
# max          47.686000
# std           3.841375

# %%
mangemangeroa = pd.read_csv('../Data/soil data/AcrossAucklandRainfallStation/mangemangeroaCombined_Data_15mins.csv', parse_dates=['Timestamp (UTC+12:00)'])
mangemangeroa.head()
# Out:
#   Timestamp (UTC+12:00)  Rain(mm)  SoilTemp(c)  SoilMoisture(%)
# 0   2014-05-28 03:00:00       0.0         17.0           44.654
# 1   2014-05-28 03:45:00       0.0         17.0           44.654
# 2   2014-05-28 04:00:00       0.0         17.0           44.654
# 3   2014-05-28 04:45:00       0.0         17.0           44.654
# 4   2014-05-28 05:00:00       0.0         17.0           44.654

# %%
tamahunga = pd.read_csv('../Data/soil data/AcrossAucklandRainfallStation/tamahungaCombined_Data_15mins.csv', parse_dates=['Timestamp (UTC+12:00)'])
tamahunga.head()
# Out:
#   Timestamp (UTC+12:00)  Rain(mm)  SoilTemp(c)  SoilMoisture(%)
# 0   2023-02-08 05:15:00       0.0         21.9           49.149
# 1   2023-02-08 05:30:00       0.0         21.9           49.148
# 2   2023-02-08 05:45:00       0.0         21.9           49.149
# 3   2023-02-08 06:00:00       0.0         21.9           49.031
# 4   2023-02-08 06:15:00       0.0         21.9           49.149

# %%
tamahunga.describe()
# Out:
#                Timestamp (UTC+12:00)      Rain(mm)   SoilTemp(c)  \
# count                          54867  54867.000000  54867.000000
# mean   2023-11-22 22:53:13.247307008      0.048841     17.667268
# min              2023-02-08 05:15:00      0.000000     10.200000
# 25%              2023-07-02 13:07:30      0.000000     14.400000
# 50%              2023-11-22 10:45:00      0.000000     17.500000
# 75%              2024-04-13 07:52:30      0.000000     20.600000
# max              2024-09-09 21:15:00     21.750000     26.600000
# std                              NaN      0.350953      3.801377
#
#        SoilMoisture(%)
# count     54867.000000
# mean         48.280474
# min          39.301000
# 25%          47.045000
# 50%          50.056000
# 75%          50.476000
# max          51.792000
# std           3.310767

# %%
tomarata = pd.read_csv('../Data/soil data/AcrossAucklandRainfallStation/tomarataCombined_Data_15mins.csv', parse_dates=['Timestamp (UTC+12:00)'])
tomarata.head()
# Out:
#   Timestamp (UTC+12:00)  Rain(mm)  SoilTemp(c)  SoilMoisture(%)
# 0   2019-05-26 04:00:00       0.0       15.229        35.790667
# 1   2019-05-26 04:15:00       0.0       15.200        33.602000
# 2   2019-05-26 04:30:00       0.0       15.200        33.602000
# 3   2019-05-26 04:45:00       0.0       15.200        33.602000
# 4   2019-05-26 05:00:00       0.0       15.200        33.605000

# %%
tomarata.describe()
# Out:
#                Timestamp (UTC+12:00)       Rain(mm)    SoilTemp(c)  \
# count                         185358  185358.000000  185358.000000
# mean   2022-01-17 07:07:14.020652544       0.042974      16.540053
# min              2019-05-26 04:00:00       0.000000       6.700000
# 25%              2020-09-19 20:48:45       0.000000      13.300000
# 50%              2022-01-16 05:07:30       0.000000      16.100000
# 75%              2023-05-17 04:26:15       0.000000      19.588000
# max              2024-09-10 21:45:00      21.000000      31.700000
# std                              NaN       0.304598       3.933627
#
#        SoilMoisture(%)
# count    185358.000000
# mean         34.975655
# min           9.017000
# 25%          28.766000
# 50%          37.900000
# 75%          42.469000
# max          53.509000
# std           9.913681

# %%
waitangi = pd.read_csv('../Data/soil data/AcrossAucklandRainfallStation/waitangiCombined_Data_15mins.csv', parse_dates=['Timestamp (UTC+12:00)'])
waitangi.head()
# Out:
#   Timestamp (UTC+12:00)  Rain(mm)  SoilTemp(c)  SoilMoisture(%)
# 0   2014-05-29 19:00:00       0.0         13.8           43.549
# 1   2014-05-29 19:15:00       0.0         13.8           43.513
# 2   2014-05-29 19:30:00       0.0         13.8           43.513
# 3   2014-05-29 19:45:00       0.0         13.8           43.549
# 4   2014-05-29 20:00:00       0.0         13.8           43.548

# %%
whangamarie = pd.read_csv('../Data/soil data/AcrossAucklandRainfallStation/whangamarieCombined_Data_15mins.csv', parse_dates=['Timestamp (UTC+12:00)'])
whangamarie.head()
# Out:
#   Timestamp (UTC+12:00)  Rain(mm)  SoilTemp(c)  SoilMoisture(%)
# 0   2014-05-28 17:15:00       0.0         13.0           44.611
# 1   2014-05-28 17:30:00       0.0         13.0           44.598
# 2   2014-05-28 17:45:00       0.0         13.0           44.600
# 3   2014-05-28 18:00:00       0.0         13.0           44.601
# 4   2014-05-28 18:15:00       0.0         13.2           44.602

# %%
whangamarie.describe()
# Out:
#                Timestamp (UTC+12:00)       Rain(mm)    SoilTemp(c)  \
# count                         278656  278656.000000  278656.000000
# mean   2019-10-08 19:02:55.038398208       0.039605      18.288529
# min              2014-05-28 17:15:00       0.000000       8.400000
# 25%              2016-05-23 09:11:15       0.000000      14.300000
# 50%              2020-09-14 09:52:30       0.000000      18.200000
# 75%              2022-09-10 05:18:45       0.000000      22.100000
# max              2024-09-10 22:15:00      48.450000      30.100000
# std                              NaN       0.300029       4.412305
#
#        SoilMoisture(%)
# count    278656.000000
# mean         44.704447
# min          31.615000
# 25%          43.633000
# 50%          44.933000
# 75%          46.368000
# max          58.854000
# std           2.637091

# %%
import matplotlib.dates as mdates
import os

station_files = [
    '../Data/soil data/AcrossAucklandRainfallStation/MtAlbert_Data_15mins.csv',
    '../Data/soil data/AcrossAucklandRainfallStation/ArarimuCombined_Data_15mins.csv',
    '../Data/soil data/AcrossAucklandRainfallStation/awhituCombined_Data_15mins.csv',
    # '../Data/soil data/AcrossAucklandRainfallStation/hoteoCombined_Data_15mins.csv',
    '../Data/soil data/AcrossAucklandRainfallStation/Kaipara_Data_15mins.csv',
    '../Data/soil data/AcrossAucklandRainfallStation/mangemangeroaCombined_Data_15mins.csv',
    # '../Data/soil data/AcrossAucklandRainfallStation/tamahungaCombined_Data_15mins.csv',
    '../Data/soil data/AcrossAucklandRainfallStation/tomarataCombined_Data_15mins.csv',
    '../Data/soil data/AcrossAucklandRainfallStation/waitangiCombined_Data_15mins.csv',
    '../Data/soil data/AcrossAucklandRainfallStation/whangamarieCombined_Data_15mins.csv'
]

for station_file in station_files:
    # Load data, parse datetime column
    station_data = pd.read_csv(station_file, parse_dates=['Timestamp (UTC+12:00)'])
    
    # Set 'Timestamp (UTC+12:00)' as the index for easier plotting of dates
    station_data.set_index('Timestamp (UTC+12:00)', inplace=True)
    
    # Plot each parameter
    plt.figure(figsize=(8, 3))
    plt.plot(station_data.index, station_data['Rain(mm)'], label='Rain (mm)')
    plt.plot(station_data.index, station_data['SoilTemp(c)'], label='Soil Temperature (°C)')
    plt.plot(station_data.index, station_data['SoilMoisture(%)'], label='Soil Moisture (%)')

    # Set x-ticks to show each year and rotate labels by 45 degrees
    plt.gca().xaxis.set_major_locator(mdates.YearLocator())
    plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))
    plt.xticks(rotation=45)
    
    # Add labels, legend, and title
    plt.xlabel("Year")
    plt.ylabel("Values")
    station_name = os.path.basename(station_file).replace('.csv', '')  # Extract station name
    plt.title(f"{station_name} Data (Rain, Soil Temperature, Soil Moisture)")
    plt.legend()
    plt.show()

# %%
import os

all_data = {'Rain(mm)': [], 'SoilTemp(c)': [], 'SoilMoisture(%)': []}

# Load data for each station and store in all_data for plotting
for station_file in station_files:
    station_name = os.path.basename(station_file).replace('.csv', '')

    # Load data, parse datetime column
    station_data = pd.read_csv(station_file, parse_dates=['Timestamp (UTC+12:00)'])
    
    # Append each parameter to its respective list
    all_data['Rain(mm)'].append((station_data.index, station_data['Rain(mm)']))
    all_data['SoilTemp(c)'].append((station_data.index, station_data['SoilTemp(c)']))
    all_data['SoilMoisture(%)'].append((station_data.index, station_data['SoilMoisture(%)']))

# Plot each parameter with data from all stations
for parameter, datasets in all_data.items():
    plt.figure(figsize=(12, 4))
    
    for i, (index, values) in enumerate(datasets):
        plt.plot(index, values, label=f'Station {i+1}')
    
    # Add labels and legend
    plt.xlabel("Index")
    plt.ylabel(parameter)
    plt.title(f"{parameter} Across All Stations")
    plt.legend()
    plt.show()
# Out:
# C:\Users\Ying\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:152: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
statistics_list = []

# Loop through each station file, load the data, and calculate statistics
for station_file in station_files:
    # Load data, parse datetime column
    station_data = pd.read_csv(station_file, parse_dates=['Timestamp (UTC+12:00)'])
    total_rainfall = 0
    total_rainfall += station_data['Rain(mm)'].sum()
    # Calculate statistics for each parameter
    stats = {
        'Station Name': os.path.basename(station_file).replace('.csv', ''),
        'Mean Rain (mm)': station_data['Rain(mm)'].mean(),
        'Median Rain (mm)': station_data['Rain(mm)'].median(),
        'Std Dev Rain (mm)': station_data['Rain(mm)'].std(),
        'Min Rain (mm)': station_data['Rain(mm)'].min(),
        'Max Rain (mm)': station_data['Rain(mm)'].max(),
        
        'Mean Soil Temp (°C)': station_data['SoilTemp(c)'].mean(),
        'Median Soil Temp (°C)': station_data['SoilTemp(c)'].median(),
        'Std Dev Soil Temp (°C)': station_data['SoilTemp(c)'].std(),
        'Min Soil Temp (°C)': station_data['SoilTemp(c)'].min(),
        'Max Soil Temp (°C)': station_data['SoilTemp(c)'].max(),
        
        'Mean Soil Moisture (%)': station_data['SoilMoisture(%)'].mean(),
        'Median Soil Moisture (%)': station_data['SoilMoisture(%)'].median(),
        'Std Dev Soil Moisture (%)': station_data['SoilMoisture(%)'].std(),
        'Min Soil Moisture (%)': station_data['SoilMoisture(%)'].min(),
        'Max Soil Moisture (%)': station_data['SoilMoisture(%)'].max(),
    }
    
    # Append statistics to the list
    statistics_list.append(stats)

# Create a DataFrame from the list of statistics
statistics_report = pd.DataFrame(statistics_list)

# Display the statistics report
print(statistics_report)
# statistics_report.to_csv("./All station Soil Report.csv")
# Out:
#                         Station Name  Mean Rain (mm)  Median Rain (mm)  \
# 0               MtAlbert_Data_15mins        0.038837               0.0
# 1        ArarimuCombined_Data_15mins        0.043513               0.0
# 2         awhituCombined_Data_15mins        0.039299               0.0
# 3                Kaipara_Data_15mins        0.033018               0.0
# 4  mangemangeroaCombined_Data_15mins        0.037616               0.0
# 5       tomarataCombined_Data_15mins        0.042974               0.0
# 6       waitangiCombined_Data_15mins        0.039195               0.0
# 7    whangamarieCombined_Data_15mins        0.039605               0.0
#
#    Std Dev Rain (mm)  Min Rain (mm)  Max Rain (mm)  Mean Soil Temp (°C)  \
# 0           0.273190            0.0          14.00            17.079976
# 1           0.298592            0.0          18.92            16.411810
# 2           0.285745            0.0          23.06            17.897929
# ...

# %% [markdown]
# Normalize data by station to make them comparable:

# %%
from sklearn.preprocessing import StandardScaler

# Apply scaling (fit on each station separately if needed)
scaler = StandardScaler()
for station_file in station_files:
    station_data[['Rain(mm)', 'SoilTemp(c)', 'SoilMoisture(%)']] = scaler.fit_transform(
        station_data[['Rain(mm)', 'SoilTemp(c)', 'SoilMoisture(%)']]
    )

# %%
normalized_data = {}

# Loop through each station file, load the data, and normalize
for station_file in station_files:
    # Load data, parse datetime column
    station_data = pd.read_csv(station_file, parse_dates=['Timestamp (UTC+12:00)'])
    
    # Initialize the StandardScaler
    scaler = StandardScaler()
    
    # Fit and transform the data
    station_data[['Rain(mm)', 'SoilTemp(c)', 'SoilMoisture(%)']] = scaler.fit_transform(
        station_data[['Rain(mm)', 'SoilTemp(c)', 'SoilMoisture(%)']]
    )
    
    # Store the normalized data
    station_name = os.path.basename(station_file).replace('.csv', '')
    normalized_data[station_name] = station_data

# Optionally, display the normalized data for one of the stations
for station_name, data in normalized_data.items():
    print(f"Normalized data for {station_name}:\n", data.head())
# Out:
# Normalized data for MtAlbert_Data_15mins:
#    Timestamp (UTC+12:00)  Rain(mm)  SoilTemp(c)  SoilMoisture(%)
# 0   2018-07-07 11:15:00 -0.142162    -1.822638        -1.179676
# 1   2018-07-07 11:30:00 -0.142162    -1.822638        -1.135066
# 2   2018-07-07 11:45:00 -0.142162    -1.822638        -1.135842
# 3   2018-07-07 12:00:00 -0.142162    -1.795353        -1.136424
# 4   2018-07-07 12:15:00 -0.142162    -1.795353        -1.137006
# Normalized data for ArarimuCombined_Data_15mins:
#    Timestamp (UTC+12:00)  Rain(mm)  SoilTemp(c)  SoilMoisture(%)  Column1
# 0   2014-05-29 03:45:00 -0.145729    -1.707896        -0.373759      NaN
# 1   2014-05-29 04:00:00 -0.145729    -1.707896        -0.373759      NaN
# 2   2014-05-29 04:15:00 -0.145729    -1.707896        -0.373759      NaN
# 3   2014-05-29 04:30:00 -0.145729    -1.758788        -0.391002      NaN
# 4   2014-05-29 04:45:00 -0.145729    -1.758788        -0.391309      NaN
# Normalized data for awhituCombined_Data_15mins:
# ...

# %%
for station_file in station_files:
    # Load data, parse datetime column
    station_data = pd.read_csv(station_file, parse_dates=['Timestamp (UTC+12:00)'])

    # Calculate correlation matrix
    correlation_matrix = station_data[['Rain(mm)', 'SoilTemp(c)', 'SoilMoisture(%)']].corr()
    
    # Print the correlation matrix with the station name
    station_name = station_file.split('/')[-1].replace('.csv', '')  
    print(f"Correlation matrix for {station_name}:")
    print(correlation_matrix)
    print("\n")
# Out:
# Correlation matrix for MtAlbert_Data_15mins:
#                  Rain(mm)  SoilTemp(c)  SoilMoisture(%)
# Rain(mm)         1.000000    -0.022556         0.058048
# SoilTemp(c)     -0.022556     1.000000        -0.551905
# SoilMoisture(%)  0.058048    -0.551905         1.000000
#
#
# Correlation matrix for ArarimuCombined_Data_15mins:
#                  Rain(mm)  SoilTemp(c)  SoilMoisture(%)
# Rain(mm)         1.000000    -0.009996         0.062104
# SoilTemp(c)     -0.009996     1.000000        -0.644560
# SoilMoisture(%)  0.062104    -0.644560         1.000000
#
#
# Correlation matrix for awhituCombined_Data_15mins:
#                  Rain(mm)  SoilTemp(c)  SoilMoisture(%)
# Rain(mm)         1.000000    -0.024317         0.064682
# SoilTemp(c)     -0.024317     1.000000        -0.737691
# SoilMoisture(%)  0.064682    -0.737691         1.000000
#
#
# Correlation matrix for Kaipara_Data_15mins:
#                  Rain(mm)  SoilTemp(c)  SoilMoisture(%)
# ...

# %% [markdown]
# Create Lag Features

# %%
df = pd.DataFrame()

for station_file in station_files:
    station_data = pd.read_csv(station_file)  
    df = pd.concat([df, station_data], ignore_index=True)

# %%
lag_days = [1, 7, 14, 30, 45]
# Create lag features
for lag in lag_days:

    df[f'SoilMoist_lag_{lag}'] = df['SoilMoisture(%)'].shift(lag)
    df[f'Rainfall_lag_{lag}'] = df['Rain(mm)'].shift(lag)
    df[f'Temperature_lag_{lag}'] = df['SoilTemp(c)'].shift(lag)

# Drop rows with NaN values created by shifting
df = df.dropna()

# %%
X = df.drop(columns=['SoilMoisture(%)'])  # Features
y = df['SoilMoisture(%)']  # Target
