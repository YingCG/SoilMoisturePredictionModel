# %% [markdown]
# # Step 1: Data Collection

# %%
# import library
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Combined data in mtalbert
mtalbert = pd.read_csv('../Data/soil data/mtalbert-648717-20241008172730/MtAlbert_Data_15mins.csv', index_col='Timestamp (UTC+12:00)', parse_dates=True)
mtalbert.head(5)

# headtail = (np.r_[0:5, -5:0])
mtalbertheadtail = mtalbert.iloc[np.r_[0:5, -5:0]]
print(mtalbertheadtail)
# Out:
#                        Rain(mm)  SoilTemp(c)  SoilMoisture(%)
# Timestamp (UTC+12:00)
# 2018-07-07 11:15:00         0.0       10.400           37.364
# 2018-07-07 11:30:00         0.0       10.400           37.594
# 2018-07-07 11:45:00         0.0       10.400           37.590
# 2018-07-07 12:00:00         0.0       10.500           37.587
# 2018-07-07 12:15:00         0.0       10.500           37.584
# 2024-10-21 19:00:00         0.0       18.391           46.736
# 2024-10-21 19:15:00         0.0       18.313           46.861
# 2024-10-21 19:30:00         0.0       18.316           46.861
# 2024-10-21 19:45:00         0.0       18.313           46.866
# 2024-10-21 20:00:00         0.0       18.316           46.903

# %%
mtalbert['Location'] = 'Mt Albert Grammar rainfall'
mtalbert['Soil Order'] = 'Ultic'
mtalbert['NZ Soil Classification'] = 'Mottled Yellow Ultic'
mtalbert['Mean annual rainfall (mm)'] = '1242'
mtalbert['Pastoral land use'] = 'Mixed dairy and drystock'
mtalbert['Ecological District'] = 'Tamaki'
mtalbert['Brackish Estuarine'] = '2057'
mtalbert['Coastal Forest'] = '309'
mtalbert['Dune Vegetation'] = '0'
mtalbert['Freshwater Wetland'] = '73'
mtalbert['Kauri Forest'] = '359'
mtalbert['Volcanic Boulderfield'] = '29'
mtalbert['Podocarp/Broadleaf & Kauri'] = '362'
mtalbert['Shrubland'] = '1174'
mtalbert['Unclassified'] = '1980'
mtalbert.head()
# mtalbert.to_csv('../EcologyDistrict/mtalbert_soil_data.csv')
# Out:
#                        Rain(mm)  SoilTemp(c)  SoilMoisture(%)  \
# Timestamp (UTC+12:00)
# 2018-07-07 11:15:00         0.0         10.4           37.364
# 2018-07-07 11:30:00         0.0         10.4           37.594
# 2018-07-07 11:45:00         0.0         10.4           37.590
# 2018-07-07 12:00:00         0.0         10.5           37.587
# 2018-07-07 12:15:00         0.0         10.5           37.584
#
#                                          Location Soil Order  \
# Timestamp (UTC+12:00)
# 2018-07-07 11:15:00    Mt Albert Grammar rainfall      Ultic
# 2018-07-07 11:30:00    Mt Albert Grammar rainfall      Ultic
# 2018-07-07 11:45:00    Mt Albert Grammar rainfall      Ultic
# 2018-07-07 12:00:00    Mt Albert Grammar rainfall      Ultic
# 2018-07-07 12:15:00    Mt Albert Grammar rainfall      Ultic
#
#                       NZ Soil Classification Mean annual rainfall (mm)  \
# Timestamp (UTC+12:00)
# 2018-07-07 11:15:00     Mottled Yellow Ultic                      1242
# ...

# %%
print("Actual column names in DataFrame:", mtalbert.columns)
# Out:
# Actual column names in DataFrame: Index(['Rain(mm)', 'SoilTemp(c)', 'SoilMoisture(%)', 'Location', 'Soil Order',
#        'NZ Soil Classification', 'Mean annual rainfall (mm)',
#        'Pastoral land use', 'Ecological District', 'Brackish Estuarine',
#        'Coastal Forest', 'Dune Vegetation', 'Freshwater Wetland',
#        'Kauri Forest', 'Volcanic Boulderfield', 'Podocarp/Broadleaf & Kauri',
#        'Shrubland', 'Unclassified'],
#       dtype='object')

# %%
# Combined data in awhitu
awhitu = pd.read_csv('../Data/soil data/Awhitu-741611-20240910095744/awhituCombined_Data_15mins.csv', index_col='Timestamp (UTC+12:00)', parse_dates=True)
awhitu.head(5)

# headtail = (np.r_[0:5, -5:0])
awhituheadtail = awhitu.iloc[np.r_[0:5, -5:0]]
print(awhituheadtail)
# Out:
#                        Rain(mm)  SoilTemp(c)  SoilMoisture(%)
# Timestamp (UTC+12:00)
# 2014-05-27 17:45:00         0.0       14.200           43.589
# 2014-05-27 18:00:00         0.0       14.200           43.587
# 2014-05-27 18:15:00         0.0       14.000           43.586
# 2014-05-27 18:30:00         0.0       14.000           43.561
# 2014-05-27 18:45:00         0.0       13.900           43.561
# 2024-09-10 20:45:00         0.0       14.212           47.973
# 2024-09-10 21:00:00         0.0       14.212           47.973
# 2024-09-10 21:15:00         0.0       14.209           48.018
# 2024-09-10 21:30:00         0.0       14.212           48.019
# 2024-09-10 21:45:00         0.0       14.212           48.019

# %%
awhitu['Location'] = 'Awhitu @ Brook Road'
awhitu['Soil Order'] = 'Granular'
awhitu['NZ Soil Classification'] = 'Typic Orthic Granular'
awhitu['Mean annual rainfall (mm)'] = '1372'
awhitu['Pastoral land use'] = 'Regional Park'
awhitu['Ecological District'] = 'Awhitu'
awhitu['Brackish Estuarine'] = '491'
awhitu['Coastal Forest'] = '161'
awhitu['Dune Vegetation'] = '0'
awhitu['Freshwater Wetland'] = '240'
awhitu['Kauri Forest'] = '0'
awhitu['Volcanic Boulderfield'] = '0'
awhitu['Podocarp/Broadleaf & Kauri'] = '1401'
awhitu['Shrubland'] = '715'
awhitu['Unclassified'] = '0'
awhitu.head()
# Out:
#                        Rain(mm)  SoilTemp(c)  SoilMoisture(%)  \
# Timestamp (UTC+12:00)
# 2014-05-27 17:45:00         0.0         14.2           43.589
# 2014-05-27 18:00:00         0.0         14.2           43.587
# 2014-05-27 18:15:00         0.0         14.0           43.586
# 2014-05-27 18:30:00         0.0         14.0           43.561
# 2014-05-27 18:45:00         0.0         13.9           43.561
#
#                                   Location Soil Order NZ Soil Classification  \
# Timestamp (UTC+12:00)
# 2014-05-27 17:45:00    Awhitu @ Brook Road   Granular  Typic Orthic Granular
# 2014-05-27 18:00:00    Awhitu @ Brook Road   Granular  Typic Orthic Granular
# 2014-05-27 18:15:00    Awhitu @ Brook Road   Granular  Typic Orthic Granular
# 2014-05-27 18:30:00    Awhitu @ Brook Road   Granular  Typic Orthic Granular
# 2014-05-27 18:45:00    Awhitu @ Brook Road   Granular  Typic Orthic Granular
#
#                       Mean annual rainfall (mm) Pastoral land use  \
# ...

# %% [markdown]
# # Step 2: Combine Data

# %%
combined_df = pd.concat([mtalbert, awhitu], axis=0, join="outer").sort_index()

combined_df
# Out:
#                        Rain(mm)  SoilTemp(c)  SoilMoisture(%)  \
# Timestamp (UTC+12:00)
# 2014-05-27 17:45:00         0.0       14.200           43.589
# 2014-05-27 18:00:00         0.0       14.200           43.587
# 2014-05-27 18:15:00         0.0       14.000           43.586
# 2014-05-27 18:30:00         0.0       14.000           43.561
# 2014-05-27 18:45:00         0.0       13.900           43.561
# ...                         ...          ...              ...
# 2024-10-21 19:00:00         0.0       18.391           46.736
# 2024-10-21 19:15:00         0.0       18.313           46.861
# 2024-10-21 19:30:00         0.0       18.316           46.861
# 2024-10-21 19:45:00         0.0       18.313           46.866
# 2024-10-21 20:00:00         0.0       18.316           46.903
#
#                                          Location Soil Order  \
# Timestamp (UTC+12:00)
# 2014-05-27 17:45:00           Awhitu @ Brook Road   Granular
# ...

# %%
# Combined data in Kaipara
Kaipara = pd.read_csv('../Data/soil data/Kaipara Heads-644211-20240909095124/Kaipara_Data_15mins.csv', index_col='Timestamp (UTC+12:00)', parse_dates=True)
Kaipara.head(5)

# headtail = (np.r_[0:5, -5:0])
Kaiparaheadtail = Kaipara.iloc[np.r_[0:5, -5:0]]
print(Kaiparaheadtail)
# Out:
#                        Rain(mm)  SoilTemp(c)  SoilMoisture(%)
# Timestamp (UTC+12:00)
# 2014-07-08 00:30:00         0.0       13.400           39.218
# 2014-07-08 00:45:00         0.0       13.300           39.220
# 2014-07-08 01:00:00         0.0       13.300           39.220
# 2014-07-08 01:15:00         0.0       13.300           39.220
# 2014-07-08 01:30:00         0.0       13.300           39.221
# 2024-09-09 20:45:00         0.0       14.675           40.810
# 2024-09-09 21:00:00         0.0       14.682           40.717
# 2024-09-09 21:15:00         0.0       14.608           40.717
# 2024-09-09 21:30:00         0.0       14.608           40.814
# 2024-09-09 21:45:00         0.0       14.600           40.817

# %%
Kaipara['Location'] = 'Kaipara Heads @ Wallers'
Kaipara['Soil Order'] = 'Brown'
Kaipara['NZ Soil Classification'] = 'Red Hill sandy loam'
Kaipara['Mean annual rainfall (mm)'] = '1054'
Kaipara['Pastoral land use'] = 'Drystock'
Kaipara['Ecological District'] = 'Kaipara'
Kaipara['Brackish Estuarine'] = '8606'
Kaipara['Coastal Forest'] = '133'
Kaipara['Dune Vegetation'] = '2151'
Kaipara['Freshwater Wetland'] = '726'
Kaipara['Kauri Forest'] = '11'
Kaipara['Volcanic Boulderfield'] = '0'
Kaipara['Podocarp/Broadleaf & Kauri'] = '1059'
Kaipara['Shrubland'] = '2935'
Kaipara['Unclassified'] = '1156'

# %%
combined_df = pd.concat([combined_df, Kaipara], axis=0, join="outer").sort_index()

# %%
# Combined data in manukau
Whangamaire = pd.read_csv('../Data/soil data/Whangamarie741813-20240910102615/whangamarieCombined_Data_15mins.csv', index_col='Timestamp (UTC+12:00)', parse_dates=True)
Whangamaire.head(5)

# headtail = (np.r_[0:5, -5:0])
Whangamarieheadtail = Whangamaire.iloc[np.r_[0:5, -5:0]]
print(Whangamarieheadtail)
# Out:
#                        SoilMoisture(%)  SoilTemp(c)  Rain(mm)
# Timestamp (UTC+12:00)
# 2014-05-28 17:15:00             44.611       13.000       0.0
# 2014-05-28 17:30:00             44.598       13.000       0.0
# 2014-05-28 17:45:00             44.600       13.000       0.0
# 2014-05-28 18:00:00             44.601       13.000       0.0
# 2014-05-28 18:15:00             44.602       13.200       0.0
# 2024-09-10 21:15:00             48.199       16.513       0.0
# 2024-09-10 21:30:00             48.199       16.513       0.0
# 2024-09-10 21:45:00             48.199       16.513       0.0
# 2024-09-10 22:00:00             48.199       16.433       0.0
# 2024-09-10 22:15:00             48.199       16.436       0.0

# %%
Whangamaire['Location'] = 'Whangamaire @ Culvert'
Whangamaire['Soil Order'] = 'Allophanic'
Whangamaire['NZ Soil Classification'] = 'Typic Orthic Allophanic'
Whangamaire['Mean annual rainfall (mm)'] = '1329'
Whangamaire['Pastoral land use'] = 'Lifestyle block'
Whangamaire['Ecological District'] = 'Manukau'
Whangamaire['Brackish Estuarine'] = '1096'
Whangamaire['Coastal Forest'] = '13'
Whangamaire['Dune Vegetation'] = '0'
Whangamaire['Freshwater Wetland'] = '105'
Whangamaire['Kauri Forest'] = '0'
Whangamaire['Volcanic Boulderfield'] = '0'
Whangamaire['Podocarp/Broadleaf & Kauri'] = '908'
Whangamaire['Shrubland'] = '271'
Whangamaire['Unclassified'] = '36'

# %%
combined_df = pd.concat([combined_df, Whangamaire], axis=0, join="outer").sort_index()

# %%
combined_df_cleaned = combined_df.dropna(axis=1)

combined_df_cleaned

# Convert columns to numeric
numeric_columns = [
    'Brackish Estuarine', 'Mean annual rainfall (mm)', 'Coastal Forest',
    'Dune Vegetation', 'Freshwater Wetland', 'Kauri Forest',
    'Volcanic Boulderfield', 'Podocarp/Broadleaf & Kauri', 'Shrubland', 'Unclassified'
]
combined_df_cleaned[numeric_columns] = combined_df_cleaned[numeric_columns].apply(pd.to_numeric)

# Convert columns to category
category_columns = [
    'Location', 'Soil Order', 'NZ Soil Classification', 'Pastoral land use', 'Ecological District'
]
combined_df_cleaned[category_columns] = combined_df_cleaned[category_columns].astype('category')

# Display the DataFrame to confirm changes
print(combined_df_cleaned.dtypes)
print(combined_df_cleaned)
# Out:
# Rain(mm)                       float64
# SoilTemp(c)                    float64
# SoilMoisture(%)                float64
# Location                      category
# Soil Order                    category
# NZ Soil Classification        category
# Mean annual rainfall (mm)        int64
# Pastoral land use             category
# Ecological District           category
# Brackish Estuarine               int64
# Coastal Forest                   int64
# Dune Vegetation                  int64
# Freshwater Wetland               int64
# Kauri Forest                     int64
# Volcanic Boulderfield            int64
# Podocarp/Broadleaf & Kauri       int64
# Shrubland                        int64
# Unclassified                     int64
# dtype: object
#                        Rain(mm)  SoilTemp(c)  SoilMoisture(%)  \
# Timestamp (UTC+12:00)
# 2014-05-27 17:45:00         0.0       14.200           43.589
# 2014-05-27 18:00:00         0.0       14.200           43.587
# ...

# %%
combined_df_cleaned['Location'].unique()
# Out:
# ['Awhitu @ Brook Road', 'Whangamaire @ Culvert', 'Kaipara Heads @ Wallers', 'Mt Albert Grammar rainfall']
# Categories (4, object): ['Awhitu @ Brook Road', 'Kaipara Heads @ Wallers', 'Mt Albert Grammar rainfall', 'Whangamaire @ Culvert']

# %%
row_2['Location'] = 'Hoteo at Oldfields'
row_2['Soil Order'] = 'Ultic'
row_2['NZ Soil Classification'] = 'Typic Yellow Ultic'
row_2['Mean annual rainfall (mm)'] = '1347'
row_2['Pastoral land use'] = 'Lifestyle block'
row_2['Ecological District'] = 'Rodney'
row_2['Brackish Estuarine'] = '1010'
row_2['Coastal Forest'] = '505'
row_2['Dune Vegetation'] = '163'
row_2['Freshwater Wetland'] = '858'
row_2['Kauri Forest'] = '762'
row_2['Volcanic Boulderfield'] = '0'
row_2['Podocarp/Broadleaf & Kauri'] = '13089'
row_2['Shrubland'] = '10643'
row_2['Unclassified'] = '2501'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[108], line 1
# ----> 1 row_2['Location'] = 'Hoteo at Oldfields'
#       2 row_2['Soil Order'] = 'Ultic'
#       3 row_2['NZ Soil Classification'] = 'Typic Yellow Ultic'
#
# NameError: name 'row_2' is not defined

# %%
row_3['Location'] = 'Tamahunga @ Quintals Rd'
row_3['Soil Order'] = 'Ultic'
row_3['NZ Soil Classification'] = 'Typic Yellow Ultic'
row_3['Mean annual rainfall (mm)'] = '1561'
row_3['Pastoral land use'] = 'Drystock'
row_3['Ecological District'] = 'Rodney'
row_3['Brackish Estuarine'] = '1010'
row_3['Coastal Forest'] = '505'
row_3['Dune Vegetation'] = '163'
row_3['Freshwater Wetland'] = '858'
row_3['Kauri Forest'] = '762'
row_3['Volcanic Boulderfield'] = '0'
row_3['Podocarp/Broadleaf & Kauri'] = '13089'
row_3['Shrubland'] = '10643'
row_3['Unclassified'] = '2501'

# %%
row_4['Location'] = 'Tomarata at Briens Farm'
row_4['Soil Order'] = 'Ultic'
row_4['NZ Soil Classification'] = 'Perch Gley or Densipan Ultic'
row_4['Mean annual rainfall (mm)'] = '1172'
row_4['Pastoral land use'] = 'Dairy'
row_4['Ecological District'] = 'Rodney'
row_4['Brackish Estuarine'] = '1010'
row_4['Coastal Forest'] = '505'
row_4['Dune Vegetation'] = '163'
row_4['Freshwater Wetland'] = '858'
row_4['Kauri Forest'] = '762'
row_4['Volcanic Boulderfield'] = '0'
row_4['Podocarp/Broadleaf & Kauri'] = '13089'
row_4['Shrubland'] = '10643'
row_4['Unclassified'] = '2501'

# %%
row_5['Location'] = 'Ararimu @ Zanders'
row_5['Soil Order'] = 'Allophanic'
row_5['NZ Soil Classification'] = 'Typic Orthic Allophanic'
row_5['Mean annual rainfall (mm)'] = '1352'
row_5['Pastoral land use'] = 'Drystock'
row_5['Ecological District'] = 'Waitakere'
row_5['Brackish Estuarine'] = '145'
row_5['Coastal Forest'] = '421'
row_5['Dune Vegetation'] = '122'
row_5['Freshwater Wetland'] = '247'
row_5['Kauri Forest'] = '1675'
row_5['Volcanic Boulderfield'] = '0'
row_5['Podocarp/Broadleaf & Kauri'] = '10670'
row_5['Shrubland'] = '8258'
row_5['Unclassified'] = '148'

# %%
row_7['Location'] = 'Mangemangeroa @ craigs'
row_7['Soil Order'] = 'Ultic'
row_7['NZ Soil Classification'] = 'Typic Yellow Ultic'
row_7['Mean annual rainfall (mm)'] = '1198'
row_7['Pastoral land use'] = 'Lifestyle block'
row_7['Ecological District'] = 'Tamaki'
row_7['Brackish Estuarine'] = '2057'
row_7['Coastal Forest'] = '309'
row_7['Dune Vegetation'] = '0'
row_7['Freshwater Wetland'] = '73'
row_7['Kauri Forest'] = '359'
row_7['Volcanic Boulderfield'] = '29'
row_7['Podocarp/Broadleaf & Kauri'] = '362'
row_7['Shrubland'] = '1174'
row_7['Unclassified'] = '1980'

# %%
row_9['Location'] = 'Waitangi @ Diver Road'
row_9['Soil Order'] = 'Granular'
row_9['NZ Soil Classification'] = 'Typic Orthic Granular'
row_9['Mean annual rainfall (mm)'] = '1280'
row_9['Pastoral land use'] = 'Dairy'
row_9['Ecological District'] = 'Manukau'
row_9['Brackish Estuarine'] = '1096'
row_9['Coastal Forest'] = '13'
row_9['Dune Vegetation'] = '0'
row_9['Freshwater Wetland'] = '105'
row_9['Kauri Forest'] = '0'
row_9['Volcanic Boulderfield'] = '0'
row_9['Podocarp/Broadleaf & Kauri'] = '908'
row_9['Shrubland'] = '271'
row_9['Unclassified'] = '36'

# %% [markdown]
# Data Transformation

# %% [markdown]
# Feature Engineering: Scaling, Normalization and Standardization

# %% [markdown]
# Feature Selection

# %% [markdown]
# Handling Imbalanced Data

# %% [markdown]
# Encoding Categorical Features

# %% [markdown]
# Data Splitting
