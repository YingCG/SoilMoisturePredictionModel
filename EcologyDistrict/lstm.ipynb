# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
mtalbert = pd.read_csv('./CombinedData/MtAlbert_Data_Hourly.csv', index_col='Timestamp (UTC+12:00)', parse_dates=True)
mtalbert.head()
# Out:
#                        Rain(mm)  Column1  SoilTemp(c)  SoilMoisture(%)
# Timestamp (UTC+12:00)
# 2019-05-26 06:00:00         0.0      0.0      14.4000        41.620375
# 2019-05-26 07:00:00         0.0      0.0      14.3625        41.610875
# 2019-05-26 08:00:00         0.0      0.0      14.3000        41.591000
# 2019-05-26 09:00:00         0.0      0.0      14.3625        41.594750
# 2019-05-26 10:00:00         0.0      0.0      14.4000        41.582875

# %%
mtalbert.index.freq = "H"
# Out:
# C:\Users\Ying\AppData\Local\Temp\ipykernel_20792\299915076.py:1: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   mtalbert.index.freq = "H"

# %%
mtalbert.plot(figsize=(12,5))
# Out:
# <Axes: xlabel='Timestamp (UTC+12:00)'>
