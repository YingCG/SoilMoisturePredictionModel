# %%
from sklearn.linear_model import LinearRegression
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('../Data/motatstation_weather_auckland_2016_2024.csv')
data
# Out:
#           Date  WDir(Deg)  WSpd(m/s)  GustDir(Deg)  GustSpd(m/s)  WindRun(Km)  \
# 0     20160301      188.0        1.2          65.0           7.2        172.0
# 1     20160302      157.0        3.2          60.0           9.3        258.0
# 2     20160303      134.0        1.9          67.0          10.8        214.0
# 3     20160304      147.0        1.3          38.0           6.2        134.0
# 4     20160305      131.0        0.4         197.0           9.3        187.0
# ...        ...        ...        ...           ...           ...          ...
# 2934  20240313      216.0        1.2         230.0           9.9        214.0
# 2935  20240314      254.0        1.4         286.0           7.7        256.0
# 2936  20240315      194.0        3.1         310.0           8.7        179.0
# 2937  20240316      219.0        3.1         216.0          11.9        244.0
# 2938  20240317      160.0        0.5         210.0           7.7        157.0
#
# ...

# %%
rain = data['Rain(mm)']
SoilMoist = data['SoilMoist(%)']
data = rain[rain > 0]
data.hist()
# Out:
# <Axes: >

# %%
data.plot.scatter(x="Rain(mm)", y='SoilMoist(%)')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 data.plot.scatter(x="Rain(mm)", y='SoilMoist(%)')
#
# File c:\Users\Ying\.conda\envs\level8\lib\site-packages\pandas\plotting\_core.py:1748, in PlotAccessor.scatter(self, x, y, s, c, **kwargs)
#    1660 def scatter(
#    1661     self,
#    1662     x: Hashable,
#    (...)
#    1666     **kwargs,
#    1667 ) -> PlotAccessor:
#    1668     """
#    1669     Create a scatter plot with varying marker point size and color.
#    1670
#    (...)
#    1746         ...                       colormap='viridis')
#    1747     """
# -> 1748     return self(kind="scatter", x=x, y=y, s=s, c=c, **kwargs)
#
# File c:\Users\Ying\.conda\envs\level8\lib\site-packages\pandas\plotting\_core.py:977, in PlotAccessor.__call__(self, *args, **kwargs)
# ...
